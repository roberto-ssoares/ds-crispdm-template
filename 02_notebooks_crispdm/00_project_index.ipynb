# %% [markdown]
# # 00 — Project Index (CRISP-DM Hub)

# %% [markdown]
# **Objetivo:** hub do projeto com links e gates.
#
# - Data: 2026-02-27
# - Parâmetros: `artifacts/00_config/params.json`

# %% [markdown]
# ## Configuração do Projeto
#
# Este notebook lê parâmetros comuns do arquivo `artifacts/00_config/params.json` para manter consistência entre fases.

# %%
import json
from pathlib import Path

PROJECT_ROOT = Path('..').resolve() if Path('.').name == 'notebooks' else Path('.').resolve()
PARAMS_PATH = PROJECT_ROOT / 'artifacts' / '00_config' / 'params.json'

with open(PARAMS_PATH, 'r', encoding='utf-8') as f:
    params = json.load(f)

params

# %% [markdown]
# ## Navegação
#
# 1. **Notebook 01** — Business Understanding + Data Understanding (EDA + Qualidade)
# 2. **Notebook 02** — Data Preparation + Feature Engineering + ABT
# 3. **Notebook 03** — Modeling + Validation (CV + GridSearch + Decisão)
# 4. **Notebook 04** — Operationalization (Salvar modelo + Inference + Submission)

# %% [markdown]
# ## Gates (Checklist rápido)
#
# ### Gate 01 — BU/DU completo
# - [ ] Objetivo, métrica e baseline definidos
# - [ ] Data Quality Report gerado
# - [ ] Achados do EDA documentados
#
# ### Gate 02 — ABT pronta
# - [ ] ABT salva em `data/03_gold/`
# - [ ] `features_manifest.json` gerado
#
# ### Gate 03 — Modelo validado
# - [ ] CV (média ± desvio) registrado
# - [ ] Benchmark + validação salvos
#
# ### Gate 04 — Operacionalização
# - [ ] Modelo salvo em `models/`
# - [ ] `submission.csv` gerado (quando Kaggle)
# - [ ] Model card gerado

# %% [markdown]
# ## Métricas e resultados (preencha ao longo do projeto)
#
# | Item | Valor |
# |---|---|
# | Métrica principal | |
# | Melhor modelo | |
# | CV (média ± std) | |
# | Kaggle Public Score | |
