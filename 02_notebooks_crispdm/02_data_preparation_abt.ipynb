# %% [markdown]
# # 02 — Data Preparation (Feature Engineering + ABT)

# %% [markdown]
# **Fase:** Data Preparation (Skill 03)
#
# **Outputs esperados:**
# - `data/03_gold/abt_train.parquet`
# - `data/03_gold/abt_test.parquet` (se existir)
# - `artifacts/02/features_manifest.json`

# %% [markdown]
# ## Configuração do Projeto
#
# Este notebook lê parâmetros comuns do arquivo `artifacts/00_config/params.json` para manter consistência entre fases.

# %%
import json
from pathlib import Path

PROJECT_ROOT = Path('..').resolve() if Path('.').name == 'notebooks' else Path('.').resolve()
PARAMS_PATH = PROJECT_ROOT / 'artifacts' / '00_config' / 'params.json'

with open(PARAMS_PATH, 'r', encoding='utf-8') as f:
    params = json.load(f)

params

# %% [markdown]
# ## 3. Data Preparation (Skill 03)
#
# ### Objetivo
# Construir ABT reprodutível e documentar features.

# %%
import pandas as pd
import numpy as np

# TODO: carregar dados (raw/clean)
# df = ...

# %% [markdown]
# ### Feature Engineering (tabela para preencher)
#
# | Feature | Origem | Transformação | Justificativa |
# |---|---|---|---|
# | | | | |

# %%
# TODO: gerar e salvar ABT
# abt_train.to_parquet(PROJECT_ROOT / params["paths"]["gold_dir"] / "abt_train.parquet", index=False)

# %%
import json

features_manifest = {
    "target": params.get("target"),
    "features": []
}

out_path = PROJECT_ROOT / "artifacts/02/features_manifest.json"
out_path.parent.mkdir(parents=True, exist_ok=True)
out_path.write_text(json.dumps(features_manifest, ensure_ascii=False, indent=2), encoding="utf-8")
out_path

# %% [markdown]
# ## ✅ Gate 02 — ABT pronta?
# - [ ] ABT salva em `data/03_gold/`
# - [ ] Manifest de features gerado
