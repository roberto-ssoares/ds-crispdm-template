# %% [markdown]
# # 01 — Business + Data Understanding (EDA + Quality)

# %% [markdown]
# **Fase(s):** Business Understanding + Data Understanding
# **Skills:** 01, 02
#
# **Outputs esperados:**
# - `artifacts/01/eda_findings.md`
# - `artifacts/01/data_quality_report.csv`
# - (opcional) `data/02_silver/dataset_clean.parquet`

# %% [markdown]
# ## Configuração do Projeto
#
# Este notebook lê parâmetros comuns do arquivo `artifacts/00_config/params.json` para manter consistência entre fases.

# %%
import json
from pathlib import Path

PROJECT_ROOT = Path('..').resolve() if Path('.').name == 'notebooks' else Path('.').resolve()
PARAMS_PATH = PROJECT_ROOT / 'artifacts' / '00_config' / 'params.json'

with open(PARAMS_PATH, 'r', encoding='utf-8') as f:
    params = json.load(f)

params

# %% [markdown]
# ## 1. Business Understanding (Skill 01)
#
# ### Objetivo da célula
# Definir problema, métrica e baseline.
#
# ### Resultados esperados
# - Problem statement + métrica + baseline + riscos

# %% [markdown]
# #### Problem Statement (preencha)
# - Problema:
# - Contexto:
# - Stakeholders:
# - Métrica principal:
# - Baseline mínimo:
# - Restrições:
# - Riscos:

# %% [markdown]
# ## ✅ Gate 01 (parcial) — Business Understanding
# - [ ] Objetivo definido
# - [ ] Métrica definida
# - [ ] Baseline definido
# - [ ] Riscos e restrições documentados

# %% [markdown]
# ## 2. Data Understanding (Skill 02)
#
# ### Objetivo
# Entender dados, explorar padrões e avaliar qualidade.
#
# ### Outputs
# - Data Quality Report
# - Achados do EDA

# %%
import pandas as pd
import numpy as np

# TODO: carregar dados raw
# df = pd.read_csv(PROJECT_ROOT / params["paths"]["raw_dir"] / "train.csv")
# df.head()

# %% [markdown]
# ### EDA (sugestão de gráficos)
# - Distribuição da target
# - Target vs categóricas (barplot)
# - Numéricas por classe da target (hist/box)
# - Correlação (numéricas)

# %% [markdown]
# ### Data Quality Checklist (preencha)
# - Missing values:
# - Tipos incorretos:
# - Categorias inconsistentes:
# - Valores fora de faixa:
# - Duplicidades:

# %%
# TODO: salvar artefatos
# (PROJECT_ROOT / "artifacts/01/eda_findings.md").write_text("...", encoding="utf-8")
# report_df.to_csv(PROJECT_ROOT / "artifacts/01/data_quality_report.csv", index=False)

# %% [markdown]
# ## ✅ Gate 01 — Pronto para Data Preparation?
# - [ ] Data Quality Report gerado
# - [ ] Achados do EDA documentados
# - [ ] Plano de limpeza definido
