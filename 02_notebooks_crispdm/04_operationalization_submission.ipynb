# %% [markdown]
# # 04 — Operationalization (Save Model + Inference + Submission)

# %% [markdown]
# **Fase:** Operationalization & Submission
#
# **Outputs esperados:**
# - `models/best_model.pkl`
# - `submissions/submission.csv`
# - `artifacts/04/model_card.md`

# %% [markdown]
# ## Configuração do Projeto
#
# Este notebook lê parâmetros comuns do arquivo `artifacts/00_config/params.json` para manter consistência entre fases.

# %%
import json
from pathlib import Path

PROJECT_ROOT = Path('..').resolve() if Path('.').name == 'notebooks' else Path('.').resolve()
PARAMS_PATH = PROJECT_ROOT / 'artifacts' / '00_config' / 'params.json'

with open(PARAMS_PATH, 'r', encoding='utf-8') as f:
    params = json.load(f)

params

# %% [markdown]
# ## 6. Operationalization & Deployment (Inference)
#
# ### Objetivo
# Salvar o modelo e aplicar em dados novos (Kaggle/teste/produção).

# %%
import os
import joblib
import pandas as pd

(PROJECT_ROOT / params["paths"]["models_dir"]).mkdir(parents=True, exist_ok=True)
(PROJECT_ROOT / params["paths"]["submissions_dir"]).mkdir(parents=True, exist_ok=True)

# %%
# TODO: treinar final e salvar
# best_model.fit(X, y)
# model_path = PROJECT_ROOT / params["paths"]["models_dir"] / "best_model.pkl"
# joblib.dump(best_model, model_path)
# model_path

# %%
# TODO: inferência e submission
# test_abt = pd.read_parquet(PROJECT_ROOT / params["paths"]["gold_dir"] / "abt_test.parquet")
# ids = test_abt["PassengerId"]
# X_test = test_abt.drop(columns=["PassengerId"])
# preds = best_model.predict(X_test)
# submission = pd.DataFrame({"PassengerId": ids, "Survived": preds.astype(int)})
# out = PROJECT_ROOT / params["paths"]["submissions_dir"] / "submission.csv"
# submission.to_csv(out, index=False)
# out

# %%
# TODO: model card
# (PROJECT_ROOT / "artifacts/04/model_card.md").write_text("...", encoding="utf-8")

# %% [markdown]
# ## ✅ Gate 04 — Operacionalização completa?
# - [ ] Modelo salvo
# - [ ] Submission gerada (se aplicável)
# - [ ] Model card produzido
